# %%
import os
import pandas as pd
from collections import Counter
from tqdm import tqdm  # specific for progress bars

# 1. SETUP: The Mapping Dictionary 
# Doing this part manually was both and tiring job
COUNTRY_MAPPING = {
    "Turkey": "Türkiye",
    "Turkiye": "Türkiye",
    "UK": "United Kingdom",
    "U.S.A.": "United States",
    "U.S.": "United States",
    "US": "United States",
    "United States of America": "United States",
    "USA": "United States",
    "the United States": "United States",
    "Republic of Turkey": "Türkiye",
    "the Republic of Turkey": "Türkiye",
    "Republic of Türkiye": "Türkiye",
    "Turkish Republic of Northern Cyprus (TRNC)": "Northern Cyprus",
    "TRNC": "Northern Cyprus",
    "Turkish Republic of Northern Cyprus": "Northern Cyprus",
    "People’s Republic of China": "China",
    "People's Republic of China": "China",
    "Republic of China" : "Taiwan",
    "Republic of China (Taiwan)": "Taiwan",
    "China (Taiwan)": "Taiwan",
    "Islamic Republic of Iran": "Iran",
    "Islamic Republic of Afghanistan": "Afghanistan",
    "State of Palestine": "Palestine",
    "Palestinian territories": "Palestine",
    "Palestinian": "Palestine",
    "Syrian Arab Republic" : "Syria",
    "UAE": "United Arab Emirates",
    "United Arab Emirates (UAE)": "United Arab Emirates",
    "Republic of Sudan": "Sudan",
    "Democratic Republic of the Congo" : "Congo",
    "Democratic Republic of Congo" : "Congo",
    "Democratic Republic of Congo (DRC)" : "Congo",
    "Republic of Congo" : "Congo",
    "Russian Federation": "Russia",
    "Republic of Armenia" : "Armenia",
    "Republic of Azerbaijan" : "Azerbaijan",
    "Kyrgyz Republic": "Kyrgyzstan",
    "Republic of Tajikistan" : "Tajikistan",
    "Republic of Kazakhstan" : "Kazakhstan",
    "Republic of Uzbekistan" : "Uzbekistan",
    "Federal Republic of Germany": "Germany",
    "Czech Republic" : "Czechia",
    "Democratic People’s Republic of Korea (DPRK)": "North Korea",
    "Democratic People’s Republic of Korea": "North Korea",
    "Democratic People's Republic of Korea": "North Korea",
    "Republic of Korea": "South Korea",
    "Republic of Korea (ROK)" : "South Korea",
    "the Republic of Korea": "South Korea",
    "ROK" : "South Korea",
    "Korea": "South Korea",
    "the Netherlands": "Netherlands",
    "Kingdom of Saudi Arabia": "Saudi Arabia",
    "Macedonia": "North Macedonia",
    "Bosnia" : "Bosnia and Herzegovina",
    "Bosnia-Herzegovina" : "Bosnia and Herzegovina",
    "Federation of Bosnia and Herzegovina" : "Bosnia and Herzegovina",
    "Federation of BiH" : "Bosnia and Herzegovina",
    "Federation of Bosnia and Herzegovina (FBiH)" : "Bosnia and Herzegovina",
    "Federation of Bosnia and Herzegovina (FBiH)" : "Bosnia and Herzegovina",
    "BiH" : "Bosnia and Herzegovina",
    "Republic of Moldova" : "Moldova",
    "Republic of Macedonia": "North Macedonia",
    "Slovak Republic" : "Slovakia",
    "Republic of Slovenia" : "Slovenia",
    "Great Britain" : "United Kingdom",
    "Britain" : "United Kingdom",
    "United Kingdom of Great Britain and Northern Ireland" : "United Kingdom",
    "The Netherlands" : "Netherlands",
    "Brunei Darussalam" : "Brunei",
    "Dominica" : "Dominican Republic",
    "Republic of Equatorial Guinea" : "Equatorial Guinea",

    # Add any new mappings you find here
}

# 2. CONFIGURATION
ROOT_DIRECTORY = 'downloaded_data'  # The folder containing CHN_exec, etc.
cumulative_counts = Counter()       # This handles the math for us

# 3. LOCATE FILES
# We walk through the folder structure to find every "news.jsonl"
files_to_process = []
for root, dirs, files in os.walk(ROOT_DIRECTORY):
    for file in files:
        if file == "news.jsonl":
            files_to_process.append(os.path.join(root, file))

print(f"Found {len(files_to_process)} news files to process.")

# 4. PROCESS FILES
for file_path in tqdm(files_to_process, desc="Processing Files"):
    try:
        # Read the file (using lines=True as per your notebook)
        df = pd.read_json(file_path, lines=True)
        
        # Check if 'entities' column exists to avoid errors
        if 'entities' not in df.columns:
            continue

        # Iterate through the rows
        for entities_dict in df['entities']:
            # Safety check: ensure entities_dict is actually a dictionary and has 'countries'
            if isinstance(entities_dict, dict) and 'countries' in entities_dict:
                countries_list = entities_dict['countries']
                
                # Normalize and count
                for country in countries_list:
                    normalized_country = COUNTRY_MAPPING.get(country, country)
                    cumulative_counts[normalized_country] += 1

    except ValueError:
        print(f"Skipping {file_path}: Invalid JSON format.")
    except Exception as e:
        print(f"Error processing {file_path}: {e}")

# 5. OUTPUT RESULTS
print("\n--- Cumulative Frequency Results ---")

# Sort by frequency (highest to lowest)
sorted_counts = cumulative_counts.most_common()

for country, count in sorted_counts:
    print(f"- {country}: {count}")

# Optional: Save to a CSV file for safekeeping
# pd.DataFrame(sorted_counts, columns=['Country', 'Count']).to_csv("total_country_counts.csv", index=False)
# Out:
# Found 248 news files to process.
# Processing Files: 100%|██████████| 248/248 [00:43<00:00,  5.75it/s]
# --- Cumulative Frequency Results ---
# - United States: 172622
# - Russia: 113772
# - United Kingdom: 62493
# - China: 61547
# - Ukraine: 61369
# - Kyrgyzstan: 53538
# - New Zealand: 49726
# - South Africa: 47001
# - Syria: 42274
# - Germany: 42221
# - India: 42127
# - Türkiye: 40479
# - France: 39649
# - Colombia: 38816
# - Japan: 36432
# - Philippines: 35095
# - Iran: 30670
# - Israel: 30483
# - Canada: 30385
# - Hungary: 30347
# - South Korea: 30272
# - Uruguay: 29630
# - United Arab Emirates: 29419
# - Spain: 27840
# - Italy: 26604
# - Indonesia: 26140
# - Afghanistan: 25440
# - Brazil: 25288
# - Georgia: 24210
# - Iraq: 24202
# - Mexico: 24107
# - Ecuador: 23732
# - Venezuela: 23362
# - Slovakia: 23318
# - Bosnia and Herzegovina: 22401
# - Peru: 22092
# - Equatorial Guinea: 21584
# - Cuba: 21419
# - Australia: 21100
# - Egypt: 20109
# - Guatemala: 20004
# - Argentina: 18771
# - Panama: 18621
# - Qatar: 18419
# - Romania: 18327
# - Netherlands: 18075
# - Armenia: 17957
# - Poland: 17951
# - Azerbaijan: 17536
# - Kazakhstan: 17262
# - Serbia: 17242
# - Pakistan: 17085
# - Jordan: 17033
# - Belarus: 16523
# - Saudi Arabia: 16479
# - Dominican Republic: 16400
# - Singapore: 16332
# - Finland: 16252
# - Estonia: 16136
# - Switzerland: 16023
# - Croatia: 15584
# - Palestine: 15580
# - Greece: 15423
# - Tajikistan: 15391
# - Chile: 15225
# - Montenegro: 14420
# - Uzbekistan: 13795
# - Costa Rica: 13661
# - Moldova: 13368
# - Sweden: 12973
# - Austria: 12830
# - Turkmenistan: 12577
# - Andorra: 12311
# - Libya: 11977
# - Belgium: 11858
# - Suriname: 11815
# - Taiwan: 11781
# - Maldives: 11720
# - Slovenia: 11505
# - Lebanon: 11279
# - Thailand: 11052
# - Norway: 10742
# - Bulgaria: 10560
# - Malaysia: 10351
# - Czechia: 10269
# - North Korea: 9996
# - Vietnam: 9903
# - Morocco: 9812
# - Latvia: 9251
# - Denmark: 9130
# - Fiji: 9058
# - Bolivia: 9045
# - Albania: 8914
# - Portugal: 8740
# - El Salvador: 8663
# - Cambodia: 8658
# - Lithuania: 8320
# - Bahrain: 8229
# - Ireland: 8171
# - Yemen: 8072
# - Kenya: 7865
# - Paraguay: 7766
# - Nigeria: 7509
# - Sudan: 7301
# - Ethiopia: 7288
# - Congo: 7131
# - Cyprus: 7087
# - Honduras: 6605
# - Seychelles: 6552
# - Tunisia: 6525
# - Myanmar: 6375
# - Kuwait: 6326
# - Bangladesh: 6285
# - Nicaragua: 6256
# - North Macedonia: 6218
# - Sri Lanka: 5988
# - Kosovo: 5938
# - Haiti: 5538
# - Somalia: 5304
# - Algeria: 5273
# - Ghana: 5089
# - Laos: 4902
# - Liberia: 4810
# - Oman: 4714
# - Mali: 4496
# - Luxembourg: 4463
# - Nepal: 4444
# - Angola: 4421
# - Jamaica: 4412
# - Rwanda: 4397
# - Belize: 4360
# - Tanzania: 4266
# - Mongolia: 4201
# - Cape Verde: 4137
# - Mozambique: 4043
# - Benin: 3908
# - Uganda: 3904
# - Samoa: 3867
# - Iceland: 3815
# - Senegal: 3799
# - Guyana: 3559
# - Brunei: 3559
# - Malta: 3542
# - Burundi: 3433
# - Zimbabwe: 3218
# - South Sudan: 3190
# - Burkina Faso: 3174
# - Timor-Leste: 3092
# - Gabon: 2814
# - Trinidad and Tobago: 2770
# - Niger: 2717
# - Madagascar: 2708
# - Soviet Union: 2682
# - Namibia: 2651
# - Mauritania: 2529
# - Cameroon: 2517
# - Zambia: 2516
# - Sierra Leone: 2402
# - Central African Republic: 2378
# - Chad: 2366
# - Guinea: 2266
# - Botswana: 2228
# - Barbados: 2159
# - Bhutan: 2045
# - Burma: 1843
# - Mauritius: 1820
# - Malawi: 1752
# - Lesotho: 1752
# - Papua New Guinea: 1751
# - DPRK: 1638
# - Viet Nam: 1577
# - Bahamas: 1555
# - Côte d'Ivoire: 1408
# - Liechtenstein: 1379
# - Togo: 1369
# - Tonga: 1347
# - Solomon Islands: 1347
# - Ivory Coast: 1337
# - Djibouti: 1299
# - Eritrea: 1233
# - Comoros: 1211
# - Lao PDR: 1172
# - The Bahamas: 1169
# - Vanuatu: 1150
# - Monaco: 1145
# - Antigua and Barbuda: 1101
# - Hong Kong: 1074
# - Vatican: 1041
# - Palau: 1027
# - Gambia: 985
# - Yugoslavia: 977
# - The United States: 973
# - Tuvalu: 944
# - San Marino: 943
# - Arab Republic of Egypt: 932
# - Republic of Croatia: 929
# - the United Kingdom: 874
# - Bolivarian Republic of Venezuela: 856
# - Surinam: 848
# - Swaziland: 840
# - Kiribati: 826
# - Northern Macedonia: 822
# - Guinea-Bissau: 806
# - Kingdom of Bahrain: 802
# - Saint Vincent and the Grenadines: 792
# - Cook Islands: 791
# - State of Qatar: 784
# - Grenada: 777
# - Republic of South Africa: 770
# - The Gambia: 768
# - Nauru: 764
# - Marshall Islands: 745
# - USSR: 736
# - DRC: 733
# - Saint Lucia: 710
# - Republic of Belarus: 684
# - Holy See: 677
# - Cabo Verde: 676
# - East Timor: 662
# - the UK: 658
# - Republic of Cyprus: 647
# - Puerto Rico: 647
# - ROC: 626
# - Hashemite Kingdom of Jordan: 622
# - Islamic Republic of Pakistan: 600
# - Czechoslovakia: 588
# - Guinea Bissau: 562
# - United Republic of Tanzania: 555
# - Republic of Maldives: 555
# - Republic of China (ROC): 549
# - Niue: 516
# - French Republic: 515
# - Republic of Seychelles: 514
# - Kingdom of the Netherlands: 512
# - Hellenic Republic: 507
# - Eswatini: 505
# - the U.S.: 492
# - Republic of India: 491
# - Aotearoa New Zealand: 484
# - the US: 480
# - Cote d'Ivoire: 467
# - Bosnia and Herzegovina (BiH): 457
# - Holland: 455
# - SINGAPORE: 452
# - Argentine Republic: 444
# - Italian Republic: 433
# - Republic of North Macedonia: 431
# - United Kingdom (UK): 428
# - South Ossetia: 428
# - the United States of America: 425
# - Federative Republic of Brazil: 420
# - RUSSIA: 415
# - Saint Kitts and Nevis: 409
# - Côte d’Ivoire: 409
# - United States of America (USA): 397
# - Republic of Serbia: 392
# - PRC: 386
# - Western Sahara: 381
# - Federated States of Micronesia: 380
# - Lao People’s Democratic Republic: 372
# - Guinea Equatorial: 372
# - Republic of Northern Macedonia: 371
# - Timor Leste: 371
# - Sultanate of Oman: 369
# - Gaza Strip: 366
# - Democratic People's Republic of Korea (DPRK): 360
# - United Mexican States: 359
# - Sao Tome and Principe: 354
# - Кыргызская Республика: 354
# - Kingdom of Cambodia: 351
# - Democratic Republic of the Congo (DRC): 349
# - Lao People's Democratic Republic: 347
# - Bharat: 345
# - Vatican City: 343
# - Republic of Indonesia: 340
# - Aruba: 338
# - Republic of Bulgaria: 331
# - Santa Lucía: 329
# - Republika Srpska: 326
# - Republic of the Congo: 310
# - State of Kuwait: 305
# - Northern Cyprus: 304
# - Gabón: 299
# - Kingdom of Morocco: 299
# - Crimea: 298
# - Palestinian Territories: 289
# - the Philippines: 286
# - Guam: 286
# - Republic of Iraq: 284
# - UNITED STATES: 281
# - Swiss Confederation: 279
# - St. Vincent and the Grenadines: 278
# - Socialist Republic of Vietnam: 274
# - Кыргызстан: 262
# - FBiH: 261
# - Palestinian Authority: 257
# - mainland China: 257
# - U.K.: 249
# - Serbia-Montenegro: 243
# - Azerbaijan Republic: 239
# - Republic of Cuba: 238
# - Mainland China: 238
# - Kingdom of Thailand: 236
# - Taiwan (Republic of China): 232
# - Republic of Singapore: 231
# - Tokelau: 231
# - Lao: 230
# - Principality of Andorra: 229
# - St. Kitts and Nevis: 229
# - Micronesia: 227
# - Kosovo-Metohija: 224
# - Wales: 222
# - Republic of Austria: 222
# - EQUATORIAL GUINEA: 219
# - Federal Democratic Republic of Ethiopia: 218
# - FYROM: 213
# - México: 213
# - Cote d’Ivoire: 212
# - United States (US): 211
# - Greenland: 206
# - Curacao: 206
# - Curaçao: 203
# - BiH (Bosnia and Herzegovina): 203
# - Gabonese Republic: 201
# - colombia: 201
# - Kyrgyz SSR: 200
# - Democratic Socialist Republic of Sri Lanka: 199
# - Union of Comoros: 195
# - St. Lucia: 192
# - Trinidad & Tobago: 192
# - Federal Republic of Nigeria: 191
# - Santo Tomé and Príncipe: 191
# - Somali: 189
# - San Vicente and Las Grenadinas: 188
# - COLOMBIA: 186
# - Republic of Colombia: 185
# - South Korea (ROK): 185
# - Congo Brazzaville: 181
# - French Guiana: 178
# - united states: 177
# - Kingdom of Belgium: 177
# - Republic of the Marshall Islands: 175
# - Republic of Ireland: 173
# - Saudi: 172
# - Federal Republic of Somalia: 171
# - russia: 170
# - the United Arab Emirates: 167
# - Democratic Republic of Timor-Leste: 167
# - Republic of Kosovo: 164
# - Chechnya: 163
# - Republic of Benin: 161
# - ROC (Republic of China): 161
# - Croatian: 158
# - Guinea Conakry: 156
# - Commonwealth of Dominica: 152
# - Republic of Poland: 151
# - Chinese Taipei: 149
# - Oriental Republic of Uruguay: 148
# - ROC (Taiwan): 147
# - The United Kingdom: 146
# - West Bank: 145
# - Palestinian state: 145
# - Falkland Islands: 145
# - State of Israel: 145
# - Nagorno-Karabakh: 144
# - UNITED STATES OF AMERICA: 144
# - Plurinational State of Bolivia: 142
# - Ottoman Empire: 141
# - Islamic Republic of Mauritania: 138
# - São Tomé and Príncipe: 137
# - Republic of Trinidad and Tobago: 136
# - Serbia and Montenegro: 135
# - United States of America (US): 132
# - Zimbabue: 131
# - Former Yugoslav Republic of Macedonia: 130
# - American Samoa: 130
# - Faso: 130
# - The Philippines: 130
# - Kingdom of Spain: 129
# - People's Republic of China (PRC): 129
# - the Czech Republic: 128
# - New Caledonia: 128
# - Artsakh: 127
# - the UAE: 125
# - the Russian Federation: 123
# - Republic of Panama: 122
# - Kingdom of Norway: 121
# - BAHRAIN: 121
# - Taiwan (ROC): 120
# - Guinea Ecuatorial: 119
# - Turks and Caicos Islands: 118
# - Republic of Lithuania: 118
# - Republic of Finland: 117
# - Gibraltar: 117
# - Republic of Kenya: 117
# - Republic of Ecuador: 117
# - Central African Republic (CAR): 116
# - ROK (South Korea): 116
# - Bermuda: 115
# - Republic of Albania: 115
# - Kingdom of Sweden: 115
# - Republic of Peru: 115
# - Syrian: 115
# - ROK (Republic of Korea): 113
# - CHINA: 113
# - Chechen Republic: 112
# - French Polynesia: 111
# - United States (U.S.): 111
# - Republic of Paraguay: 111
# - Republic of the Philippines: 111
# - ukraine: 110
# - North Korea (DPRK): 110
# - Grand Duchy of Luxembourg: 109
# - Philippine: 109
# - Lebanese Republic: 108
# - Serbian: 108
# - Benín: 108
# - Hawaii: 108
# - Somaliland: 107
# - Kosovo and Metohija: 107
# - the Republic of Tajikistan: 106
# - San Vicente and the Grenadines: 106
# - United States (USA): 104
# - Papua: 104
# - Soviet: 103
# - Republic of Suriname: 102
# - Catalonia: 102
# - Republic of Chile: 102
# - Republic of Palau: 101
# - Cayman Islands: 101
# - United State: 100
# - Commonwealth of Australia: 99
# - Россия: 99
# - Burma/Myanmar: 99
# - Republic of Angola: 97
# - Republic of the Union of Myanmar: 97
# - Southern Sudan: 97
# - DPRK (North Korea): 97
# - The UK: 97
# - Korea (South): 96
# - Faroe Islands: 95
# - Russian Empire: 95
# - Sint Maarten: 95
# - Republic of Liberia: 95
# - NZ: 95
# - British Virgin Islands: 94
# - Democratic Popular Republic of Korea: 94
# - San Cristóbal and Nieves: 93
# - Chinese People’s Republic: 93
# - Santo Tomé and Prince: 92
# - Montserrat: 91
# - Cooperative Republic of Guyana: 91
# - the Kingdom of the Netherlands: 91
# - People’s Republic of Bangladesh: 90
# - Socialist Republic of Viet Nam: 90
# - The United States of America: 89
# - the Kingdom of Saudi Arabia: 87
# - Luxemburg: 86
# - Antigua & Barbuda: 86
# - South African Republic: 86
# - CAR: 86
# - Kingdom of Denmark: 85
# - the former Yugoslav Republic of Macedonia: 84
# - Republic of Ghana: 84
# - Republic of Burundi: 83
# - Trinidad: 83
# - ECUATORIAL GUINEA: 83
# - Republic of Mauritius: 82
# - the People's Republic of China: 82
# - IRAQ: 82
# - Burkina-Faso: 81
# - Rome: 81
# - MALAYSIA: 81
# - Republic of Guinea: 81
# - Republic of Rwanda: 80
# - Kingdom of Lesotho: 80
# - Russia Federation: 80
# - Macau: 80
# - FIJI: 80
# - Guinea Ecuadorial: 80
# - Republic of Zimbabwe: 79
# - The Republic of Korea: 79
# - UnitedStates: 79
# - Republic of Estonia: 78
# - Republic of Zambia: 77
# - People's Republic of Bangladesh: 77
# - Bosnia Herzegovina: 76
# - Republic of Latvia: 76
# - The U.S.: 76
# - INDIA: 76
# - Republic of Namibia: 76
# - RUSSIAN FEDERATION: 76
# - Republic of Yemen: 75
# - Republic of Guatemala: 75
# - Republic of Marshall Islands: 75
# - Kingdom of Tonga: 74
# - Korea (Republic of): 74
# - the Republic of Uzbekistan: 74
# - Republic of Abkhazia: 74
# - Anguilla: 73
# - People’s Republic of China (PRC): 73
# - JAPAN: 73
# - the People’s Republic of China: 73
# - Republic of Botswana: 72
# - Republic of Senegal: 72
# - the Maldives: 72
# - Saint Christopher and Nevis: 72
# - Korea (North): 72
# - Slovak: 72
# - Republic of Tunisia: 71
# - Republic of Mozambique: 71
# - the Republic of Kazakhstan: 71
# - Democratic Republic of Korea: 71
# - Belarús: 70
# - DR Congo: 70
# - cuba: 70
# - Republic of Tatarstan: 70
# - Republic of San Marino: 69
# - San Vicente and the Granada: 69
# - Macao: 68
# - Republic of Uganda: 68
# - U.A.E.: 68
# - ISRAEL: 68
# - The Commonwealth of The Bahamas: 68
# - AFGHANISTAN: 68
# - germany: 67
# - Union of the Comoros: 67
# - San Cristóbal y Nieves: 67
# - Republic of Korea (South Korea): 67
# - fYROM: 67
# - Slovenian: 66
# - 中国: 66
# - Republic of Italy: 65
# - china: 65
# - Republic of El Salvador: 65
# - AUSTRALIA: 65
# - Salvador: 65
# - St Maarten: 65
# - St. Christopher and Nevis: 65
# - Negara Brunei Darussalam: 65
# - PNG: 64
# - People's Democratic Republic of Algeria: 63
# - Congo-Brazzaville: 63
# - East Germany: 62
# - Republic of Turkiye: 62
# - south africa: 62
# -  Cambodia: 61
# - Кыргыз Республикасы: 61
# - Barbuda: 60
# - Brazilian: 60
# - Việt Nam: 60
# - Kingdom of Swaziland: 60
# - Myanmar (Burma): 59
# - Republic of Mali: 59
# - Perú: 59
# - GDR: 59
# - IRAN: 59
# - Federal Republic of Yugoslavia: 59
# - West Germany: 59
# - South China Sea: 59
# - france: 58
# - St Lucia: 58
# - Republic of Niger: 58
# - The People's Republic of China: 58
# - Kingdom of Eswatini: 57
# - Herzegovina: 57
# - venezuela: 57
# - MEXICO: 57
# - Republic of South Sudan: 56
# - Antigua: 56
# - Falklands: 56
# - DPRK (Democratic People's Republic of Korea): 56
# - Brasil: 56
# - Bulgarian: 56
# - Republic of Djibouti: 55
# - Türkiye (Turkey): 55
# - Singapur: 55
# - ECUADORIAL GUINEA: 55
# - Kingdom of Bhutan: 54
# - Federal Democratic Republic of Nepal: 54
# - Republic of Costa Rica: 54
# - Kenia: 54
# - Principality of Liechtenstein: 53
# - Santa Lucia: 53
# - iraq: 53
# - Eastern Republic of Uruguay: 52
# - St Kitts and Nevis: 52
# - China (PRC): 52
# - UKRAINE: 52
# - Burmese: 51
# - Myanmar/Burma: 51
# - St Vincent and the Grenadines: 51
# - United States of America (U.S.): 51
# - Ecuadorial Guinea: 51
# - United_Kingdom: 50
# - Republic of Nauru: 50
# - EGYPT: 50
# - Republic of Nicaragua: 50
# - uk: 50
# - Republic of Malta: 49
# - People’s Democratic Republic of Algeria: 49
# - Republic of Sierra Leone: 49
# - Irish: 49
# - Bosnia-Hercegovina: 49
# - Pilipinas: 49
# - Federation of Russia: 48
# - eSwatini: 48
# - Republic of Hungary: 48
# - สหรัฐอเมริกา: 48
# - Timor: 47
# - Principality of Monaco: 46
# - the USA: 46
# - israel: 46
# - Co-operative Republic of Guyana: 46
# - Nazi Germany: 46
# - Palestinian National Authority: 46
# - Federation of BiH (Bosnia and Herzegovina): 46
# - Bután: 46
# - República Dominicana: 46
# - Estados Unidos: 46
# - MONTENEGRO: 46
# - united kingdom: 45
# - the ROK: 45
# - PAKISTAN: 45
# - Cote D’Ivoire: 45
# - Burma (Myanmar): 45
# - Palestinian State: 44
# - Montenegrin: 44
# - mexico: 44
# - india: 44
# - Кыргыз Республика: 44
# - Commonwealth of The Bahamas: 43
# - United Kingdom of Great Britain: 43
# - Danish: 43
# - Laos (Lao PDR): 43
# - the Slovak Republic: 43
# - Republic of Kiribati: 42
# - España: 42
# - Republic of Honduras: 42
# - the Soviet Union: 42
# - japan: 42
# - Austrian Republic: 42
# - the Kyrgyz Republic: 42
# - INDONESIA: 41
# - Occupied Palestinian Territories: 41
# - Kurdistan: 41
# - Беларусь: 41
# - Côte d Ivoire: 41
# - CANADA: 41
# - Bosnia & Herzegovina: 40
# - Geneva: 40
# - georgia: 40
# - Togolese Republic: 40
# - Burkina: 40
# - Tunisian Republic: 40
# - indonesia: 40
# - REPUBLIC OF SINGAPORE: 40
# - ecuador: 40
# - us: 40
# - Republic of Malawi: 40
# - The Maldives: 40
# - Cote D'Ivoire: 39
# - turkey: 39
# - Republic of Chad: 39
# - uruguay: 39
# - peru: 39
# - iran: 39
# - Republic of Haiti: 39
# - Popular Republic of China: 39
# - Maldivas: 39
# - Latvian: 39
# - United Arab Emirates (EAU): 39
# - Dominican Republic (RD): 39
# - the Republic of Moldova: 38
# - ITALY: 38
# - GERMANY: 38
# - TURKEY: 38
# - United Kingdom of Great Britain and Ireland of the North: 38
# - Suazilandia: 38
# - Botsuana: 38
# - North Korean: 38
# - afghanistan: 37
# - croatia: 37
# - Panamá: 37
# - Palestinian territory: 37
# - Democratic Republic of Sao Tome and Principe: 37
# - Maryland: 37
# - Turks and Caicos: 37
# - RS: 37
# - syria: 37
# - PRC (People's Republic of China): 37
# - R.O.K.: 37
# - The Czech Republic: 36
# - Commonwealth of the Bahamas: 36
# - Republic of Artsakh: 36
# - Republic of Madagascar: 36
# - SAUDI ARABIA: 36
# - Union of Myanmar: 36
# - singapore: 36
# - Sri Lankan: 36
# - Camerún: 36
# - the Kingdom of Cambodia: 36
# - SAMOA: 36
# - chile: 35
# - Republic of the Sudan: 35
# - DRC (Democratic Republic of Congo): 35
# - FRANCE: 35
# - PALESTINE: 35
# - UNITED KINGDOM: 35
# - Scandinavia: 35
# - Byelorussia: 35
# - Republic of Cameroon: 35
# - Ecuatorial Guinea: 35
# - Donbass: 35
# - Vatican City State: 34
# - Hellenic Republic (Greece): 34
# - Republic of France: 34
# - the Republic of Azerbaijan: 34
# - new zealand: 34
# - The State of Qatar: 34
# - German Democratic Republic: 34
# - Comoras: 34
# - philippines: 34
# - Saharawi Arab Democratic Republic: 34
# - CUBA: 34
# - united states of america: 33
# - Republic of Fiji: 33
# - the Republic of Belarus: 33
# - brazil: 33
# - the Republic of South Africa: 33
# - the Kingdom of Bahrain: 33
# - The Russian Federation: 33
# - São Tomé e Príncipe: 33
# - 美国: 33
# - Chinese People's Republic: 33
# - ไทย: 33
# - Campuchia: 33
# - 新加坡: 33
# - Republic of Vanuatu: 32
# - Argentine: 32
# - Kingdom of Netherlands: 32
# - argentina: 32
# - Азербайджан: 32
# - The Republic of China: 32
# - greece: 31
# - Republic of South Korea: 31
# - Palestinian Territory: 31
# - Union of Soviet Socialist Republics: 31
# - SYRIA: 31
# - San Vicente and Las Granada: 31
# - Austria-Hungary: 30
# - canada: 30
# - Papua New Guinea (PNG): 30
# - The People’s Republic of China: 30
# - Independent State of Samoa: 30
# - Great Britain and Northern Ireland: 30
# - San Vicente and Las Granadinas: 30
# - Gujarati: 30
# - Juzbekistan: 30
# - Republic of Crimea: 30
# - Jersey: 29
# - Artsakh Republic: 29
# - Армения: 29
# - the Republic of China: 29
# - Kirgizstan: 29
# - THAILAND: 29
# - hungary: 29
# - Soviet Russia: 29
# - 柬埔寨: 29
# - RDC: 28
# - The Kingdom of the Netherlands: 28
# - spain: 28
# - Republic of Srpska: 28
# - Socialist Federal Republic of Yugoslavia: 28
# - the Republic of Slovenia: 28
# - Guayana: 28
# - Yibuti: 28
# - Moroccan: 28
# - egypt: 28
# - Malaya: 28
# - Hong Kong SAR: 28
# - East Timor (Timor-Leste): 28
# - Donetsk People’s Republic: 28
# - Singapour: 28
# - Republic of Montenegro: 27
# - the Republic of the Congo: 27
# - poland: 27
# - BRAZIL: 27
# - Independent State of Papua New Guinea: 27
# - Aotearoa (New Zealand): 27
# - Kosova: 26
# - Comores: 26
# - AU: 26
# - Republic of Cape Verde: 26
# - Tayikistan: 26
# - Republic of Lebanon: 26
# - SOUTH KOREA: 26
# - the Republic of Maldives: 26
# - Federation of BiH (FBiH): 26
# - slovakia: 26
# - pakistan: 26
# - the United Kingdom of Great Britain and Northern Ireland: 26
# - Algerian Republic: 26
# - Timor del Este: 26
# - the Republic of Cyprus: 26
# - KENYA: 26
# - Vatican State: 25
# - the Republic of India: 25
# - jordan: 25
# - Israel-Palestine: 25
# - 日本: 25
# - Tunis: 25
# - Federal Republic of Brazil: 25
# - Republic of Portugal: 25
# - The US: 25
# - equatorial guinea: 25
# - Italia: 25
# - Sri-Lanka: 25
# - slovenia: 25
# - The Republic of China (Taiwan): 25
# - Bharat (India): 25
# - Vkyrgyzstan: 25
# - ประเทศไทย: 25
# - Lesoto: 24
# - São Tomé and Principe: 24
# - italy: 24
# - serbia: 24
# - Francia: 24
# - New Jersey: 24
# - costa rica: 24
# - the Republic of the Union of Myanmar: 24
# - St. Vincent & the Grenadines: 24
# - Comoros Union: 24
# - Macedonia*: 24
# - D.P.R.K.: 24
# - Russian Federation (Russia): 24
# - RSFSR: 24
# - Ruanda: 23
# - United Arab Emirates (U.A.E.): 23
# - Federation of Saint Kitts and Nevis: 23
# - norway: 23
# - switzerland: 23
# - Holy See (Vatican): 23
# - Российская Федерация: 23
# - Republic of Guinea-Bissau: 23
# - Gulf of Guinea: 23
# - estonia: 23
# - Kazakstan: 23
# - the Republic of Korea (ROK): 23
# - US (United States): 23
# - ECUADOR: 23
# - United States (Washington): 23
# - Isle of Man: 23
# - The Republic of Equatorial Guinea: 23
# - الأردن: 23
# - Казахстан: 23
# - NORTH KOREA: 23
# - bosnia and herzegovina: 22
# - United States of Mexico: 22
# - the Democratic Republic of the Congo: 22
# - China (People's Republic of China): 22
# - Georgian: 22
# - JORDAN: 22
# - SPAIN: 22
# - POLAND: 22
# - Greek Republic: 22
# - The Republic of Tajikistan: 22
# - Turks and Caicos Islands (TCI): 22
# - British Empire: 22
# - Sao Tomé and Príncipe: 22
# - the DRC: 22
# - San Vicente and Granada: 22
# - kenya: 22
# - Curazao: 22
# - Sint Eustatius: 22
# - Union of Soviet Socialist Republics (USSR): 22
# - Laos PDR: 22
# - Czechoslovak Republic: 22
# - GEORGIA: 22
# - Iraqi Kurdistan: 22
# - भारत: 22
# - The Republic of Kazakhstan: 22
# - สหรัฐอาเมริกา: 22
# - NEW ZEALAND: 22
# - australia: 21
# - netherlands: 21
# - Republic of Turkmenistan: 21
# - Republic of Argentina: 21
# - belarus: 21
# - Nagorno Karabakh: 21
# - Federated States of Micronesia (FSM): 21
# - the State of Qatar: 21
# - Bénin: 21
# - SUDAN: 21
# - Socialist Federal Republic of Yugoslavia (SFRY): 21
# - Trinidad y Tobago: 21
# - Tobago: 21
# - Brunéi Darussalam: 21
# - Iran (Islamic Republic of): 21
# - Estonian Republic: 21
# - West Papua: 21
# - kazakhstan: 21
# - U.S. Virgin Islands: 21
# - Китай: 21
# - The Republic of Uzbekistan: 21
# - albania: 20
# - Eastern Timor: 20
# - The Kingdom of Saudi Arabia: 20
# - Republic of Gambia: 20
# - guatemala: 20
# - finland: 20
# - QATAR: 20
# - KSA: 20
# - BH: 20
# - SFRY: 20
# - Chili: 20
# - Democratic Saharawi Arab Republic: 20
# - Costa de Ivory: 20
# - Fiji Islands: 20
# - Kampuchea: 20
# - Saharawi Arab Republic: 20
# -  Latvia: 20
# - RMI: 20
# - PRC (China): 20
# - Kingdom of Saudi Arabia (KSA): 20
# - จีน: 20
# - NETHERLANDS: 20
# - Solomons: 20
# - Taiwan (as ROC): 20
# - Guernsey: 19
# - St. Kitts & Nevis: 19
# - UAE (United Arab Emirates): 19
# - Israel/Palestine: 19
# - Republic of Kyrgyzstan: 19
# - the Islamic Republic of Iran: 19
# - Republic of Côte d'Ivoire: 19
# - the State of Israel: 19
# - United Kingdom of Great Britain and Ireland: 19
# - north korea: 19
# - Hong Kong, China: 19
# - Republic of Cabo Verde: 19
# - St. Vincent: 19
# - Macedonian: 19
# - Macedonia del Norte: 19
# - south korea: 19
# - Wallis and Futuna: 19
# - Rhodesia: 19
# - VIETNAM: 19
# - DENMARK: 19
# - BELGIUM: 19
# - Western Australia: 19
# - the ROC: 19
# - Republic of Karakalpakstan: 19
# - Central African Republic (RCA): 18
# - TÃ¼rkiye: 18
# - Basque Country: 18
# - lebanon: 18
# - Dagestan: 18
# - Republic of Greece: 18
# - Republic of the Maldives: 18
# - paraguay: 18
# - panama: 18
# - the Republic of Armenia: 18
# - armenia: 18
# - azerbaijan: 18
# - Турция: 18
# - Republic of Bosnia and Herzegovina: 18
# - the Republic of China (Taiwan): 18
# - Sahrawi Arab Democratic Republic: 18
# - Saharawi Democratic Republic: 18
# - the U.K.: 18
# - Republic of Togo: 18
# - the United States (US): 18
# - the Republic of the Philippines: 18
# - Mauricio: 18
# - the Republic of Trinidad and Tobago: 18
# - GREECE: 18
# -  United States: 18
# - Donetsk: 18
# - romania: 18
# - NORWAY: 18
# - Pitcairn Islands: 18
# - Northern Mariana Islands: 18
# - Lao People’s Democratic Republic (Lao PDR): 18
# - Republic of Cote d'Ivoire: 18
# - Германия: 18
# - Кыргыз Республикасынын: 18
# - PHL: 18
# - TAIWAN: 18
# - South African Government: 18
# - kosovo: 17
# - sweden: 17
# - Bosnia and Hercegovina: 17
# - Republic of Iceland: 17
# - Comoros Islands: 17
# -  Bahamas: 17
# -  Mozambique: 17
# - 伊拉克: 17
# - The Holy See: 17
# - austria: 17
# - Comoro Islands: 17
# - Latvian Republic: 17
# - morocco: 17
# - the Republic of North Macedonia: 17
# - qatar: 17
# - Peoples Republic of China: 17
# - The Slovak Republic: 17
# - Near East: 17
# - former Yugoslav Republic of Macedonia: 17
# - Republic of The Gambia: 17
# - the Republic of Indonesia: 17
# - the Republic of Equatorial Guinea: 17
# - Ivory Coast (Côte d'Ivoire): 17
# - Rumania: 17
# - United Kingdom (London): 17
# - VENEZUELA: 17
# - PERU: 17
# - Comorian: 17
# - Sahara: 17
# - Bolivarian Republic: 17
# - North Sudan: 17
# - South-Africa: 17
# - the Vatican: 17
# - Hong Kong China: 17
# - the United States (U.S.): 17
# - RD Congo: 17
# - Taiwan Strait: 17
# - moldova: 17
# - the PRC: 17
# - Skyrgyzstan: 17
# - Узбекистан: 17
# - Singapura: 17
# - R.O.C.: 17
# - Democratic Republic of Congo (RDC): 16
# - European Economic Area: 16
# - ireland: 16
# - Republic of Ukraine: 16
# - State of Libya: 16
# - Guinea-Conakry: 16
# - Bahrein: 16
# - kyrgyzstan: 16
# - FSM: 16
# - the State of Kuwait: 16
# - LEBANON: 16
# - IRELAND: 16
# - Palestine/Israel: 16
# - Saint Vincent: 16
# - palestine: 16
# - Gran Colombia: 16
# - Central and Eastern European Countries (CEEC): 16
# - NewZealand: 16
# - ghana: 16
# - FYR Macedonia: 16
# - Iraqi: 16
# - Romanian Government: 16
# - montenegro: 16
# - St. Maarten: 16
# - RoK: 16
# - Republic of Sakha (Yakutia): 16
# - 法国: 16
# - DPR: 16
# - French Guyana: 15
# - Vatican (Holy See): 15
# - united arab emirates: 15
# - The Republic of Moldova: 15
# - Benin Republic: 15
# - the Republic of Seychelles: 15
# - SWITZERLAND: 15
# - the United Kingdom (UK): 15
# - Federal Republic of Bosnia and Herzegovina (FBiH): 15
# - the Sultanate of Oman: 15
# - Democratic People’s Republic of Korea (North Korea): 15
# - Republic of Gabon: 15
# - Pacific Island Countries (PICs): 15
# - Democratic People's Republic of Korea (North Korea): 15
# - United States of North America: 15
# - Saint Martin: 15
# - People´s Republic of China: 15
# - SVG: 15
# - China-Taiwan: 15
# - libya: 15
# - the Palestinian Territories: 15
# - Lietuva: 15
# - Timor Oriental: 15
# - The Republic of Croatia: 15
# - Republic of Korea (R.O.K.): 15
# - Izkyrgyzstan: 15
# - Itajikistan: 15
# - Kyrgyz Republic (Kyrgyzstan): 15
# - Rossiya: 15
# - กัมพูชา: 15
# - Aotearoa/New Zealand: 15
# - New_Zealand: 15
# - Commonwealth of the Northern Mariana Islands: 15
# - KAZAKHSTAN: 15
# - suriname: 15
# - Karakalpakstan: 15
# - Austro-Hungarian Empire: 14
# - Saint Vincent & the Grenadines: 14
# - Republic of Georgia: 14
# - the Bahamas: 14
# - Lithuanian Republic: 14
# - Côte-d'Ivoire: 14
# - the Former Yugoslav Republic of Macedonia: 14
# - United Kingdom of Great Britain and Northern Ireland (UK): 14
# - saudi arabia: 14
# - BANGLADESH: 14
# - the Dominican Republic: 14
# - nicaragua: 14
# - Corea: 14
# - malaysia: 14
# - United Mexican States (Mexico): 14
# - Kirghizstan: 14
# - South Vietnam: 14
# - PHILIPPINES: 14
# - Bangladés: 14
# - JAMAICA: 14
# - vietnam: 14
# - Ethopia: 14
# - Western Samoa: 14
# -  Hungary: 14
# - The Republic of South Africa: 14
# - Vafganistan: 14
# - Kyrgyzstana: 14
# - Таджикистан: 14
# - SWEDEN: 14
# - Lugansk People’s Republic: 14
# - KOSOVO: 14
# - Cameroun: 13
# - Guinea-Equatorial: 13
# - the Republic of Croatia: 13
# - bahrain: 13
# - ARGENTINA: 13
# - Lao People's Democratic Republic (Lao PDR): 13
# - belgium: 13
# - United Kingdom (Brexit): 13
# -  Russia: 13
# - KUWAIT: 13
# - UNITED ARAB EMIRATES: 13
# - the Republic of Iraq: 13
# - Bosnia and Herzegovina (FBiH): 13
# - Republic of Slovakia: 13
# - Kazajistan: 13
# - Democratic Republic of São Tomé and Príncipe: 13
# - The Republic of Indonesia: 13
# - State of Eritrea: 13
# - The Dominican Republic: 13
# - South Korea (Republic of Korea): 13
# - Korea (South Korea): 13
# - Popular Democratic Republic of Korea: 13
# - U.S: 13
# - czech republic: 13
# - GUATEMALA: 13
# - Russia/Soviet Union: 13
# - The Former Yugoslav Republic of Macedonia: 13
# - Ecuatoguinea: 13
# - ES: 13
# - the United Republic of Tanzania: 13
# - CHILE: 13
# - the United Mexican States: 13
# - Vkyrgyz Republic: 13
# - Киргизия: 13
# - Венгрия: 13
# - Україна: 13
# - Maldivians: 13
# - Lugansk: 13
# - LITHUANIA: 13
# - Singapores: 13
# - Democratic Korea: 13
# - Peopleâs Republic of China: 13
# - Côte D'Ivoire: 12
# - the Holy See: 12
# - Azerbaidjan: 12
# - the French Republic: 12
# - The United Arab Emirates: 12
# - honduras: 12
# - Hong Kong Special Administrative Region: 12
# - LATVIA: 12
# - Central African: 12
# - Sao Tomé and Principle: 12
# - the Emirates: 12
# - the Republic of Macedonia: 12
# - the Republic of Northern Macedonia: 12
# - People’s Democratic Republic of Korea: 12
# - Turks & Caicos Islands: 12
# - Federal Republic of Bosnia and Herzegovina: 12
# - Korean Republic: 12
# - The Republic of Turkey: 12
# - Holy See (Vatican City): 12
# - Dubai (UAE): 12
# - the DPRK: 12
# - russian federation: 12
# - Nevis: 12
# - San Vicente y las Granadinas: 12
# - Djibuti: 12
# - Côte D’Ivoire: 12
# - LAOS: 12
# - thailand: 12
# - dominican republic: 12
# - Central American region: 12
# - Brunéi: 12
# - CAR (Central African Republic): 12
# - United_States: 12
# - the Federal Republic of Germany: 12
# - Belorussia: 12
# - latvia: 12
# - REPUBLIC OF KOREA: 12
# - BELARUS: 12
# - FYROM (North Macedonia): 12
# - The Republic of The Gambia: 12
# - إسرائيل: 12
# - KYRGYZSTAN: 12
# - Kыргызская Республика: 12
# - 韩国: 12
# - เวียดนาม: 12
# - RWANDA: 12
# - the Marshall Islands: 12
# - The Republic of Maldives: 12
# - South Australia: 12
# - Donetsk People's Republic: 12
# - ESTONIA: 12
# - Frans-Guyana: 12
# - Republic of China on Taiwan: 12
# - R.O.C. (Taiwan): 12
# -  Angola: 11
# - Galicia: 11
# - Saint Kitts: 11
# - San Vicente y las Granadas: 11
# - The former Yugoslav Republic of Macedonia: 11
# - denmark: 11
# - Republic of Vietnam: 11
# - Азербайджанская Республика: 11
# - Украина: 11
# - FINLAND: 11
# - BRITAIN: 11
# - The Kingdom of Morocco: 11
# - Republic of BiH: 11
# - Republika Srpska (RS): 11
# - Katar: 11
# - Kirghizia: 11
# - bolivia: 11
# - the Syrian Arab Republic: 11
# - Hongkong: 11
# - Sénégal: 11
# - Transdniestria: 11
# - Republic of the Gambia: 11
# - Sudan del Sur: 11
# - San Vicente y Las Granadinas: 11
# - Democratic Republic of Santo Tomé and Prince: 11
# - Malasia: 11
# - Azerbaiyan: 11
# - Korea Republic: 11
# - Saharawi Democratic Arab Republic: 11
# - Sao Tome: 11
# - Brunei-Darussalam: 11
# - Democratic People´s Republic of Korea: 11
# - the Arab Republic of Egypt: 11
# - sri lanka: 11
# - FYROM (Former Yugoslav Republic of Macedonia): 11
# - the former Soviet Union: 11
# - Israel/Palestinian Territories: 11
# - maldives: 11
# - Republic of Guinea Ecuadorial: 11
# - Republic of Korea (RoK): 11
# - Yakutia: 11
# - Қазақстан: 11
# - Индия: 11
# - កម្ពុជា (Cambodia): 11
# - MOLDOVA: 11
# - Federation of Saint Christopher and Nevis: 11
# - The Republic of Panama: 11
# - Palestina: 10
# - the Federated States of Micronesia: 10
# - Афганистан: 10
# - Turks & Caicos: 9
# - The Republic of Belarus: 9
# - Cayman: 9
# - Caribbean Netherlands: 8
# - Commonwealth of the Northern Mariana Islands (CNMI): 8
# - Франция: 6
# - Швейцария: 6
# - TURKMENISTAN: 6
# - Бulgaria: 2
# - Guinée: 2
# - Канада: 2
# - Италия: 2
# - Sint-Maarten: 2
# - Soudan: 1
# - Faroes: 1
# - Faroe: 1
# - Австрия: 1
# - Faroese Islands: 1

# %% [markdown]
# Now, to continue in the next steps, I am discarding the freqs below 1000

# %%
import os
import pandas as pd
from collections import Counter
from tqdm import tqdm

# 1. SETUP: The Updated Mapping Dictionary (From your latest file)
COUNTRY_MAPPING = {
    "Turkey": "Türkiye",
    "Turkiye": "Türkiye",
    "UK": "United Kingdom",
    "U.S.A.": "United States",
    "U.S.": "United States",
    "US": "United States",
    "United States of America": "United States",
    "USA": "United States",
    "the United States": "United States",
    "Republic of Turkey": "Türkiye",
    "the Republic of Turkey": "Türkiye",
    "Republic of Türkiye": "Türkiye",
    "Turkish Republic of Northern Cyprus (TRNC)": "Northern Cyprus",
    "TRNC": "Northern Cyprus",
    "Turkish Republic of Northern Cyprus": "Northern Cyprus",
    "People’s Republic of China": "China",
    "People's Republic of China": "China",
    "Republic of China" : "Taiwan",
    "Republic of China (Taiwan)": "Taiwan",
    "China (Taiwan)": "Taiwan",
    "Islamic Republic of Iran": "Iran",
    "Islamic Republic of Afghanistan": "Afghanistan",
    "State of Palestine": "Palestine",
    "Palestinian territories": "Palestine",
    "Palestinian": "Palestine",
    "Syrian Arab Republic" : "Syria",
    "UAE": "United Arab Emirates",
    "United Arab Emirates (UAE)": "United Arab Emirates",
    "Republic of Sudan": "Sudan",
    "Democratic Republic of the Congo" : "Congo",
    "Democratic Republic of Congo" : "Congo",
    "Democratic Republic of Congo (DRC)" : "Congo",
    "Republic of Congo" : "Congo",
    "Russian Federation": "Russia",
    "Republic of Armenia" : "Armenia",
    "Republic of Azerbaijan" : "Azerbaijan",
    "Kyrgyz Republic": "Kyrgyzstan",
    "Republic of Tajikistan" : "Tajikistan",
    "Republic of Kazakhstan" : "Kazakhstan",
    "Republic of Uzbekistan" : "Uzbekistan",
    "Federal Republic of Germany": "Germany",
    "Czech Republic" : "Czechia",
    "Democratic People’s Republic of Korea (DPRK)": "North Korea",
    "Democratic People’s Republic of Korea": "North Korea",
    "Democratic People's Republic of Korea": "North Korea",
    "Republic of Korea": "South Korea",
    "Republic of Korea (ROK)" : "South Korea",
    "the Republic of Korea": "South Korea",
    "ROK" : "South Korea",
    "Korea": "South Korea",
    "the Netherlands": "Netherlands",
    "Kingdom of Saudi Arabia": "Saudi Arabia",
    "Macedonia": "North Macedonia",
    "Bosnia" : "Bosnia and Herzegovina",
    "Bosnia-Herzegovina" : "Bosnia and Herzegovina",
    "Federation of Bosnia and Herzegovina" : "Bosnia and Herzegovina",
    "Federation of BiH" : "Bosnia and Herzegovina",
    "Federation of Bosnia and Herzegovina (FBiH)" : "Bosnia and Herzegovina",
    "BiH" : "Bosnia and Herzegovina",
    "Republic of Moldova" : "Moldova",
    "Republic of Macedonia": "North Macedonia",
    "Slovak Republic" : "Slovakia",
    "Republic of Slovenia" : "Slovenia",
    "Great Britain" : "United Kingdom",
    "Britain" : "United Kingdom",
    "United Kingdom of Great Britain and Northern Ireland" : "United Kingdom",
    "The Netherlands" : "Netherlands",
    "Brunei Darussalam" : "Brunei",
    "Dominica" : "Dominican Republic",
    "Republic of Equatorial Guinea" : "Equatorial Guinea",
}

# 2. CONFIGURATION
ROOT_DIRECTORY = 'downloaded_data'
MIN_FREQUENCY = 1000   # Filter threshold
OUTPUT_FILE = 'filtered_country_counts.csv'

cumulative_counts = Counter()

# 3. LOCATE FILES
files_to_process = []
for root, dirs, files in os.walk(ROOT_DIRECTORY):
    for file in files:
        if file == "news.jsonl":
            files_to_process.append(os.path.join(root, file))

print(f"Found {len(files_to_process)} news files to process.")

# 4. PROCESS FILES
for file_path in tqdm(files_to_process, desc="Processing Files"):
    try:
        df = pd.read_json(file_path, lines=True)
        
        if 'entities' not in df.columns:
            continue

        for entities_dict in df['entities']:
            if isinstance(entities_dict, dict) and 'countries' in entities_dict:
                countries_list = entities_dict['countries']
                
                for country in countries_list:
                    # Normalize using the updated mapping
                    normalized_country = COUNTRY_MAPPING.get(country, country)
                    cumulative_counts[normalized_country] += 1

    except ValueError:
        pass # Skip malformed files silently
    except Exception as e:
        print(f"Error processing {file_path}: {e}")

# 5. FILTER AND SAVE
print("\n--- Filtering and Saving ---")

# Filter: Keep only countries with count >= 1000
filtered_data = {k: v for k, v in cumulative_counts.items() if v >= MIN_FREQUENCY}

# Sort highest to lowest
sorted_filtered_data = dict(sorted(filtered_data.items(), key=lambda item: item[1], reverse=True))

if not sorted_filtered_data:
    print("No countries found with frequency >= 1000.")
else:
    # Convert to DataFrame and Save to CSV
    df_result = pd.DataFrame(list(sorted_filtered_data.items()), columns=['Country', 'Frequency'])
    df_result.to_csv(OUTPUT_FILE, index=False)
    
    print(f"Success! Saved {len(df_result)} countries to '{OUTPUT_FILE}'.")
    print(df_result.head(10)) # Preview top 10
# Out:
# Found 248 news files to process.
# Processing Files: 100%|██████████| 248/248 [00:42<00:00,  5.84it/s]
# --- Filtering and Saving ---
# Success! Saved 189 countries to 'filtered_country_counts.csv'.
#           Country  Frequency
# 0   United States     172622
# 1          Russia     113772
# 2  United Kingdom      62493
# 3           China      61547
# 4         Ukraine      61369
# 5      Kyrgyzstan      53538
# 6     New Zealand      49726
# 7    South Africa      47001
# 8           Syria      42274
# 9         Germany      42221
